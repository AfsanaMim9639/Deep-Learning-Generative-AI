# %% [markdown]
# <!DOCTYPE html>
# <html lang="bn">
# <head>
#   <meta charset="UTF-8">
#   <title>ফরোয়ার্ড প্রপাগেশন ও চেইন রুল</title>
#   <style>
#     body {
#       font-family: 'Siyam Rupali', Arial, sans-serif;
#       background-color: #f4f9ff;
#       padding: 30px;
#       color: #333;
#       line-height: 1.8;
#     }
#     h1, h2 {
#       color: #0d47a1;
#     }
#     .formula, .diagram, .example {
#       background: #e3f2fd;
#       padding: 15px;
#       border-left: 5px solid #2196f3;
#       margin: 20px 0;
#       font-family: monospace;
#     }
#     .summary {
#       background: #fff9c4;
#       padding: 15px;
#       border-left: 5px solid #fbc02d;
#       margin-top: 20px;
#     }
#     code {
#       background-color: #f1f1f1;
#       padding: 2px 4px;
#       font-family: Consolas, monospace;
#     }
#   </style>
# </head>
# <body>
#
#   <h1>🔁 ফরোয়ার্ড প্রপাগেশন ও চেইন রুল ব্যাখ্যা (বাংলায়)</h1>
#
#   <h2>📘 ফরোয়ার্ড প্রপাগেশন কী?</h2>
#   <p>নিউরাল নেটওয়ার্কে ইনপুট থেকে আউটপুট পর্যন্ত তথ্য প্রবাহিত হওয়ার প্রক্রিয়াকে <strong>ফরোয়ার্ড প্রপাগেশন</strong> বলে। প্রতিটি লেয়ারে:</p>
#   <div class="formula">
#     z = w × x + b<br>
#     a = σ(z)
#   </div>
#   <p>এখানে,<br>
#     - <code>w</code>: ওজন<br>
#     - <code>x</code>: ইনপুট<br>
#     - <code>b</code>: বায়াস<br>
#     - <code>σ(z)</code>: অ্যাক্টিভেশন ফাংশন (যেমন Sigmoid, ReLU)<br>
#     - <code>a</code>: আউটপুট
#   </p>
#
#   <h2>🧠 চেইন রুল দিয়ে ডেরিভেটিভ</h2>
#   <p>যদি আমাদের লস ফাংশন হয় <code>L</code> এবং আউটপুট হয় <code>a = σ(z)</code>, তাহলে চেইন রুল অনুযায়ী:</p>
#   <div class="formula">
#     dL/dw = dL/da × da/dz × dz/dw
#   </div>
#
#   <h2>🧮 উদাহরণ:</h2>
#   <p>ধরুন,</p>
#   <div class="formula">
#     ŷ = σ(w × x + b)<br>
#     L = (ŷ - y)<sup>2</sup> / 2
#   </div>
#   <p>তাহলে চেইন রুল প্রয়োগ করে:</p>
#   <div class="formula">
#     dL/dw = (ŷ - y) × σ′(z) × x
#   </div>
#   <p>যেখানে <code>σ′(z) = σ(z) × (1 - σ(z))</code></p>
#
#   <h2>🌳 চেইন রুল ডায়াগ্রাম:</h2>
#   <div class="diagram">
#     x → z = w·x + b → a = σ(z) → L = (a - y)<sup>2</sup>
#   </div>
#   <p>ডেরিভেটিভ: dL/dx = dL/da × da/dz × dz/dx</p>
#
#   <div class="summary">
#     <h2>🔄 সংক্ষেপে:</h2>
#     <ul>
#       <li>ফরোয়ার্ড প্রপাগেশন: ইনপুট থেকে আউটপুট পর্যন্ত গণনা</li>
#       <li>ব্যাকওয়ার্ড প্রপাগেশন: চেইন রুল দিয়ে ডেরিভেটিভ গণনা</li>
#       <li>প্রতিটি ধাপে চেইন রুলের মাধ্যমে গ্র্যাডিয়েন্ট হিসাব হয়</li>
#     </ul>
#   </div>
#
# </body>
# </html>
